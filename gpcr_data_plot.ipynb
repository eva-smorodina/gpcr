# %%
import os
import pandas as pd
import matplotlib.pyplot as plt

# %%
group_names_1 = ['Non-olfactory receptors', 'Olfactory receptors']
group_size_1 = [406, 420]
group_names_2 = ['', '']
group_size_2 = [18, 21, 18, 106, 243, 419, 1]

fig, ax = plt.subplots(dpi=500)
ax.axis('equal')

radius = 2
size = 0.4

purples = plt.cm.Purples

nested_pie_1, _ = ax.pie(group_size_1, radius=radius-1*size, #labels=group_names_1, 
                         wedgeprops=dict(width=size, edgecolor='k', linewidth=0.1), startangle=90,
                         colors=['#660BAB', '#FFF700'])

nested_pie_2, _ = ax.pie(group_size_2, radius=radius-2*size,# labels=group_names_2, 
                         wedgeprops=dict(width=size, edgecolor='k', linewidth=0.1), startangle=90,
                         colors=[purples(0.1), purples(0.2), purples(0.3), purples(0.4), purples(0.5), '#FFFB73', '#FFF700'])

    
plt.margins(0,0)
plt.show()
